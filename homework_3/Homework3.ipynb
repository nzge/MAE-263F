# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output # Only for iPython

# %% [markdown]
# #Helper function

# %%
def crossMat(a):
    """
    Returns the cross product matrix of vector 'a'.

    Parameters:
    a : np.ndarray
        A 3-element array representing a vector.

    Returns:
    A : np.ndarray
        The cross product matrix corresponding to vector 'a'.
    """
    A = np.array([[0, -a[2], a[1]],
                  [a[2], 0, -a[0]],
                  [-a[1], a[0], 0]])

    return A

# %% [markdown]
# #Gradient and Hessian of elastic energies

# %%
def gradEb(xkm1, ykm1, xk, yk, xkp1, ykp1, curvature0, l_k, EI):
    """
    Returns the derivative of bending energy E_k^b with respect to
    x_{k-1}, y_{k-1}, x_k, y_k, x_{k+1}, and y_{k+1}.

    Parameters:
    xkm1, ykm1 : float
        Coordinates of the previous node (x_{k-1}, y_{k-1}).
    xk, yk : float
        Coordinates of the current node (x_k, y_k).
    xkp1, ykp1 : float
        Coordinates of the next node (x_{k+1}, y_{k+1}).
    curvature0 : float
        Discrete natural curvature at node (xk, yk).
    l_k : float
        Voronoi length of node (xk, yk).
    EI : float
        Bending stiffness.

    Returns:
    dF : np.ndarray
        Derivative of bending energy.
    """

    # Nodes in 3D
    node0 = np.array([xkm1, ykm1, 0.0])
    node1 = np.array([xk, yk, 0])
    node2 = np.array([xkp1, ykp1, 0])

    # Unit vectors along z-axis
    m2e = np.array([0, 0, 1])
    m2f = np.array([0, 0, 1])

    kappaBar = curvature0

    # Initialize gradient of curvature
    gradKappa = np.zeros(6)

    # Edge vectors
    ee = node1 - node0
    ef = node2 - node1

    # Norms of edge vectors
    norm_e = np.linalg.norm(ee)
    norm_f = np.linalg.norm(ef)

    # Unit tangents
    te = ee / norm_e
    tf = ef / norm_f

    # Curvature binormal
    kb = 2.0 * np.cross(te, tf) / (1.0 + np.dot(te, tf))

    chi = 1.0 + np.dot(te, tf)
    tilde_t = (te + tf) / chi
    tilde_d2 = (m2e + m2f) / chi

    # Curvature
    kappa1 = kb[2]

    # Gradient of kappa1 with respect to edge vectors
    Dkappa1De = 1.0 / norm_e * (-kappa1 * tilde_t + np.cross(tf, tilde_d2))
    Dkappa1Df = 1.0 / norm_f * (-kappa1 * tilde_t - np.cross(te, tilde_d2))

    # Populate the gradient of kappa
    gradKappa[0:2] = -Dkappa1De[0:2]
    gradKappa[2:4] = Dkappa1De[0:2] - Dkappa1Df[0:2]
    gradKappa[4:6] = Dkappa1Df[0:2]

    # Gradient of bending energy
    dkappa = kappa1 - kappaBar
    dF = gradKappa * EI * dkappa / l_k

    return dF

# %%
def hessEb(xkm1, ykm1, xk, yk, xkp1, ykp1, curvature0, l_k, EI):
    """
    Returns the Hessian (second derivative) of bending energy E_k^b
    with respect to x_{k-1}, y_{k-1}, x_k, y_k, x_{k+1}, and y_{k+1}.

    Parameters:
    xkm1, ykm1 : float
        Coordinates of the previous node (x_{k-1}, y_{k-1}).
    xk, yk : float
        Coordinates of the current node (x_k, y_k).
    xkp1, ykp1 : float
        Coordinates of the next node (x_{k+1}, y_{k+1}).
    curvature0 : float
        Discrete natural curvature at node (xk, yk).
    l_k : float
        Voronoi length of node (xk, yk).
    EI : float
        Bending stiffness.

    Returns:
    dJ : np.ndarray
        Hessian of bending energy.
    """

    # Nodes in 3D
    node0 = np.array([xkm1, ykm1, 0])
    node1 = np.array([xk, yk, 0])
    node2 = np.array([xkp1, ykp1, 0])

    # Unit vectors along z-axis
    m2e = np.array([0, 0, 1])
    m2f = np.array([0, 0, 1])

    kappaBar = curvature0

    # Initialize gradient of curvature
    gradKappa = np.zeros(6)

    # Edge vectors
    ee = node1 - node0
    ef = node2 - node1

    # Norms of edge vectors
    norm_e = np.linalg.norm(ee)
    norm_f = np.linalg.norm(ef)

    # Unit tangents
    te = ee / norm_e
    tf = ef / norm_f

    # Curvature binormal
    kb = 2.0 * np.cross(te, tf) / (1.0 + np.dot(te, tf))

    chi = 1.0 + np.dot(te, tf)
    tilde_t = (te + tf) / chi
    tilde_d2 = (m2e + m2f) / chi

    # Curvature
    kappa1 = kb[2]

    # Gradient of kappa1 with respect to edge vectors
    Dkappa1De = 1.0 / norm_e * (-kappa1 * tilde_t + np.cross(tf, tilde_d2))
    Dkappa1Df = 1.0 / norm_f * (-kappa1 * tilde_t - np.cross(te, tilde_d2))

    # Populate the gradient of kappa
    gradKappa[0:2] = -Dkappa1De[0:2]
    gradKappa[2:4] = Dkappa1De[0:2] - Dkappa1Df[0:2]
    gradKappa[4:6] = Dkappa1Df[0:2]

    # Compute the Hessian (second derivative of kappa)
    DDkappa1 = np.zeros((6, 6))

    norm2_e = norm_e**2
    norm2_f = norm_f**2

    Id3 = np.eye(3)

    # Helper matrices for second derivatives
    tt_o_tt = np.outer(tilde_t, tilde_t)
    tmp = np.cross(tf, tilde_d2)
    tf_c_d2t_o_tt = np.outer(tmp, tilde_t)
    kb_o_d2e = np.outer(kb, m2e)

    D2kappa1De2 = (2 * kappa1 * tt_o_tt - tf_c_d2t_o_tt - tf_c_d2t_o_tt.T) / norm2_e - \
                  kappa1 / (chi * norm2_e) * (Id3 - np.outer(te, te)) + \
                  (kb_o_d2e + kb_o_d2e.T) / (4 * norm2_e)

    tmp = np.cross(te, tilde_d2)
    te_c_d2t_o_tt = np.outer(tmp, tilde_t)
    tt_o_te_c_d2t = te_c_d2t_o_tt.T
    kb_o_d2f = np.outer(kb, m2f)

    D2kappa1Df2 = (2 * kappa1 * tt_o_tt + te_c_d2t_o_tt + te_c_d2t_o_tt.T) / norm2_f - \
                  kappa1 / (chi * norm2_f) * (Id3 - np.outer(tf, tf)) + \
                  (kb_o_d2f + kb_o_d2f.T) / (4 * norm2_f)
    D2kappa1DeDf = -kappa1 / (chi * norm_e * norm_f) * (Id3 + np.outer(te, tf)) \
                  + 1.0 / (norm_e * norm_f) * (2 * kappa1 * tt_o_tt - tf_c_d2t_o_tt + \
                  tt_o_te_c_d2t - crossMat(tilde_d2))
    D2kappa1DfDe = D2kappa1DeDf.T

    # Populate the Hessian of kappa
    DDkappa1[0:2, 0:2] = D2kappa1De2[0:2, 0:2]
    DDkappa1[0:2, 2:4] = -D2kappa1De2[0:2, 0:2] + D2kappa1DeDf[0:2, 0:2]
    DDkappa1[0:2, 4:6] = -D2kappa1DeDf[0:2, 0:2]
    DDkappa1[2:4, 0:2] = -D2kappa1De2[0:2, 0:2] + D2kappa1DfDe[0:2, 0:2]
    DDkappa1[2:4, 2:4] = D2kappa1De2[0:2, 0:2] - D2kappa1DeDf[0:2, 0:2] - \
                         D2kappa1DfDe[0:2, 0:2] + D2kappa1Df2[0:2, 0:2]
    DDkappa1[2:4, 4:6] = D2kappa1DeDf[0:2, 0:2] - D2kappa1Df2[0:2, 0:2]
    DDkappa1[4:6, 0:2] = -D2kappa1DfDe[0:2, 0:2]
    DDkappa1[4:6, 2:4] = D2kappa1DfDe[0:2, 0:2] - D2kappa1Df2[0:2, 0:2]
    DDkappa1[4:6, 4:6] = D2kappa1Df2[0:2, 0:2]

    # Hessian of bending energy
    dkappa = kappa1 - kappaBar
    dJ = 1.0 / l_k * EI * np.outer(gradKappa, gradKappa)
    dJ += 1.0 / l_k * dkappa * EI * DDkappa1

    return dJ

# %%
def gradEs(xk, yk, xkp1, ykp1, l_k, EA):
    """
    Calculate the gradient of the stretching energy with respect to the coordinates.

    Args:
    - xk (float): x coordinate of the current point
    - yk (float): y coordinate of the current point
    - xkp1 (float): x coordinate of the next point
    - ykp1 (float): y coordinate of the next point
    - l_k (float): reference length
    - EA (float): elastic modulus

    Returns:
    - F (np.array): Gradient array
    """
    F = np.zeros(4)
    F[0] = -(1.0 - np.sqrt((xkp1 - xk)**2.0 + (ykp1 - yk)**2.0) / l_k) * ((xkp1 - xk)**2.0 + (ykp1 - yk)**2.0)**(-0.5) / l_k * (-2.0 * xkp1 + 2.0 * xk)
    F[1] = -(0.1e1 - np.sqrt((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k) * ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1) / l_k * (-0.2e1 * ykp1 + 0.2e1 * yk)
    F[2] = -(0.1e1 - np.sqrt((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k) * ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1) / l_k * (0.2e1 * xkp1 - 0.2e1 * xk)
    F[3] = -(0.1e1 - np.sqrt((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k) * ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1) / l_k * (0.2e1 * ykp1 - 0.2e1 * yk)

    F = 0.5 * EA * l_k * F  # Scale by EA and l_k

    return F

# %%
def hessEs(xk, yk, xkp1, ykp1, l_k, EA):
    """
    This function returns the 4x4 Hessian of the stretching energy E_k^s with
    respect to x_k, y_k, x_{k+1}, and y_{k+1}.
    """
    J = np.zeros((4, 4))  # Initialize the Hessian matrix
    J11 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (-2 * xkp1 + 2 * xk) ** 2) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * ((-2 * xkp1 + 2 * xk) ** 2) / 0.2e1 - 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k
    J12 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (-2 * ykp1 + 2 * yk) * (-2 * xkp1 + 2 * xk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (-2 * xkp1 + 2 * xk) * (-2 * ykp1 + 2 * yk) / 0.2e1
    J13 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * xkp1 - 2 * xk) * (-2 * xkp1 + 2 * xk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (-2 * xkp1 + 2 * xk) * (2 * xkp1 - 2 * xk) / 0.2e1 + 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k
    J14 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * ykp1 - 2 * yk) * (-2 * xkp1 + 2 * xk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (-2 * xkp1 + 2 * xk) * (2 * ykp1 - 2 * yk) / 0.2e1
    J22 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (-2 * ykp1 + 2 * yk) ** 2) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * ((-2 * ykp1 + 2 * yk) ** 2) / 0.2e1 - 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k
    J23 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * xkp1 - 2 * xk) * (-2 * ykp1 + 2 * yk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (-2 * ykp1 + 2 * yk) * (2 * xkp1 - 2 * xk) / 0.2e1
    J24 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * ykp1 - 2 * yk) * (-2 * ykp1 + 2 * yk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (-2 * ykp1 + 2 * yk) * (2 * ykp1 - 2 * yk) / 0.2e1 + 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k
    J33 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * xkp1 - 2 * xk) ** 2) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * ((2 * xkp1 - 2 * xk) ** 2) / 0.2e1 - 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k
    J34 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * ykp1 - 2 * yk) * (2 * xkp1 - 2 * xk)) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * (2 * xkp1 - 2 * xk) * (2 * ykp1 - 2 * yk) / 0.2e1
    J44 = (1 / ((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) / l_k ** 2 * (2 * ykp1 - 2 * yk) ** 2) / 0.2e1 + (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.3e1 / 0.2e1)) / l_k * ((2 * ykp1 - 2 * yk) ** 2) / 0.2e1 - 0.2e1 * (0.1e1 - np.sqrt(((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2)) / l_k) * (((xkp1 - xk) ** 2 + (ykp1 - yk) ** 2) ** (-0.1e1 / 0.2e1)) / l_k

    J = np.array([[J11, J12, J13, J14],
                   [J12, J22, J23, J24],
                   [J13, J23, J33, J34],
                   [J14, J24, J34, J44]])

    J *= 0.5 * EA * l_k

    return J

# %% [markdown]
# # Functions to create elastic force vector and its Hessian

# %%
def getFs(q, EA, deltaL):
  # q - DOF vector of size N
  # EA - stretching stiffness
  # deltaL - undeformed reference length (assume to be a scalar for this simple example)
  # Output:
  # Fs - a vector (negative gradient of elastic stretching force)
  # Js - a matrix (negative hessian of elastic stretching force)

  ndof = q.size # Number of DOFs
  N = ndof // 2 # Number of nodes

  Fs = np.zeros(ndof) # stretching force
  Js = np.zeros((ndof, ndof))

  for k in range(0, N-1):
      # May need to modify if network of beams
      # k-th stretching spring (USE A LOOP for the general case
      xkm1 = q[2*k] # x coordinate of the first node
      ykm1 = q[2*k+1] # y coordinate of the first node
      xk = q[2*k+2] # x coordinate of the second node
      yk = q[2*k+3] # y coordinate of the second node
      ind = np.arange(2*k, 2*k+4) # 0, 1, 2, 3 for k = 0
      gradEnergy = gradEs(xkm1, ykm1, xk, yk, deltaL, EA)
      hessEnergy = hessEs(xkm1, ykm1, xk, yk, deltaL, EA)

      Fs[ind] -= gradEnergy # force = - gradient of energy. Fs is the stretching force
      Js[np.ix_(ind, ind)] -= hessEnergy # index vector: 0:4

  return Fs, Js

# %%
def getFb(q, EI, deltaL):
  # q - DOF vector of size N
  # EI - bending stiffness
  # deltaL - undeformed Voronoi length (assume to be a scalar for this simple example)
  # Output:
  # Fb - a vector (negative gradient of elastic stretching force)
  # Jb - a matrix (negative hessian of elastic stretching force)

  ndof = q.size # Number of DOFs
  N = ndof // 2 # Number of nodes

  Fb = np.zeros(ndof) # bending force
  Jb = np.zeros((ndof, ndof))

  # First bending spring (USE A LOOP for the general case)
  for k in range(1, N-1):
    xkm1 = q[2*k-2] # x coordinate of the first node
    ykm1 = q[2*k-1] # y coordinate of the first node
    xk = q[2*k] # x coordinate of the second node
    yk = q[2*k+1] # y coordinate of the second node
    xkp1 = q[2*k+2] # x coordinate of the third node
    ykp1 = q[2*k+3] # y coordinate of the third node
    ind = np.arange(2*k-2, 2*k+4)
    gradEnergy = gradEb(xkm1, ykm1, xk, yk, xkp1, ykp1, 0, deltaL, EI)
    hessEnergy = hessEb(xkm1, ykm1, xk, yk, xkp1, ykp1, 0, deltaL, EI)

    Fb[ind] -= gradEnergy # force = - gradient of energy. Fb is the stretching force
    Jb[np.ix_(ind, ind)] -= hessEnergy # index vector: 0:6

  return Fb, Jb

# %% [markdown]
# # Objective Function or Integrator
#
# Given the old position and the old velocity, find out th new position and the new velocity

# %%
def objfun(q_old, u_old, dt, tol, maximum_iter,
           m, mMat, # inertia
           EI, EA, # elastic stiffness
           W, C, # external force
           deltaL,
           free_index):

  q_new = q_old.copy() # Guess solution

  # Newton Raphson
  iter_count = 0 # number of iterations
  error = tol * 10 # error
  flag = 1 # if flag = 1, it is a good solution

  while error > tol:
    # Inertia
    F_inertia = m/dt * ((q_new - q_old) / dt - u_old)
    J_inertia = mMat / dt ** 2

    # Elastic forces: Stretching and Bending
    Fs, Js = getFs(q_new, EA, deltaL)
    Fb, Jb = getFb(q_new, EI, deltaL)
    F_elastic = Fs + Fb
    J_elastic = Js + Jb

    # External forces
    # Viscous force
    Fv = - C @ ( q_new - q_old ) / dt
    Jv = - C / dt

    # Equations of motion
    f = F_inertia - F_elastic - Fv - W
    J = J_inertia - J_elastic - Jv

    f_free = f[free_index]
    J_free = J[np.ix_(free_index, free_index)]

    # Newton's update (all DOFs are FREE)
    dq_free = np.linalg.solve(J_free, f_free)
    q_new[free_index] = q_new[free_index] - dq_free

    # Get the error
    error = np.linalg.norm(f_free)

    # Update the iteration number
    iter_count += 1
    if iter_count > maximum_iter:
      flag = -1 # Return with an error signal
      print("Maximum number of iterations reached.")
      return q_new, flag

    # u_new = (q_new - q_old) / dt # Velocity
  return q_new, flag

# %%
def equilibrium_solver(q_old, u_old, dt, tol, maximum_iter,
                       m, mMat, EI, EA, W, C, deltaL,
                       free_index, controlState, controlNode):
    """
    Wraps your existing objfun() but updates the control node BC
    according to the current control state u = [x_c, y_c, theta_c].
    """
    q_guess = q_old.copy()

    # Apply control node position/orientation
    q_guess[2*controlNode-2] = controlState[0]
    q_guess[2*controlNode-1] = controlState[1]

    # Set orientation for (n-1) node based on theta_c
    vec_desired = deltaL * np.array([np.cos(controlState[2]), np.sin(controlState[2])])
    q_guess[2*controlNode-4:2*controlNode-2] = q_guess[2*controlNode-2:2*controlNode] - vec_desired

    print(f"Control Node Position: x = {q_guess[2*controlNode-2]:.4f}, y = {q_guess[2*controlNode-1]:.4f}. Orientation: theta = {controlState[2]:.4f} rad")
    
    # Run your Newton-Raphson equilibrium solver
    q_new, flag = objfun(q_guess, u_old, dt, tol, maximum_iter,
                         m, mMat, EI, EA, W, C, deltaL,
                         free_index)

    return q_new, flag

# %% [markdown]
# # Main

# %%
nv = 19 # number of nodes/vertices
ndof = 2 * nv
midNode = nv//2 + 1
controlNode = nv

# Rod length
RodLength = 1 # meter

# Discrete length / reference length
deltaL = RodLength / (nv - 1)

# Radii of spheres (given)
R = np.zeros(nv)
r = np.zeros(nv)
for k in range(nv):
  R[k] = 0.013 # meter
  r[k] = 0.011 # meter

# Densities
rho_alu = 2700 # kg/m^3
rho_gl = 0 # kg/m^3
rho = rho_alu  - rho_gl

# Cross sectional radius
r0 = 1e-3 # meter

# Young's modulus
Y = 1e9

# Viscosity
visc = 0 # Pa-s

# %%
# Utility quantites
ne = nv - 1 # number of edges
A = np.pi * (R**2 - r**2) # cross-sectional area of each sphere
I = np.pi * (R**4 - r**4) / 4 # area moment of inertia
EI = Y * I[0]
EA = Y * A[0]

# Geometry
nodes = np.zeros((nv, 2))
for c in range(nv):
  nodes[c, 0] = c * deltaL # x-coordinate
  nodes[c, 1] = 0.0 # y-coordinate

# Mass vector and matrix
m = np.zeros( 2 * nv )
for k in range(0, nv):
  m[2*k] =  rho_alu * A[k] * RodLength / (nv - 1) # mass of k-th node along x
  m[2*k + 1] =  rho_alu * A[k] * RodLength / (nv - 1)# mass of k-th node along y
mMat = np.diag(m)

# Gravity (external force)
W = np.zeros( 2 * nv)
g = np.array([0, -9.8]) # m/s^2
for k in range(0, nv):
  W[2*k] = 4.0 / 3.0 * np.pi * R[k]**3 * rho * g[0] # Weight along x
  W[2*k+1] = 4.0 / 3.0 * np.pi * R[k]**3 * rho * g[1] # Weight along y
# Gradient of W = 0

# Viscous damping (external force)
C = np.zeros((2 * nv, 2 * nv))
for k in range(0, nv):
  C[2*k, 2*k] = 6.0 * np.pi * visc * R[k] # Damping along x for k-th node
  C[2*k+1, 2*k+1] = 6.0 * np.pi * visc * R[k] # Damping along y for k-th node

# %%
# Maximum number of iterations
maximum_iter = 1000

# Tolerance
tol = EI / RodLength ** 2 * 1e-3 # Newton-Raphson tolerance
# print(f"Tolerance: {tol}")

# Time step
dt = 0.05 # second
# Total time
totalTime = 1 # second

# Variables related to plotting
saveImage = 0
plotStep = int(totalTime/dt  * (1/5)) # Save 5 images over the simulation
print(plotStep)
# Out:
# 4

# %% [markdown]
# **Boundary Conditions**
#
# In this example, the boundary conditions do not change with time and, therefore, we can compute the free_index (corresponding to free DOFs) and fixed_index (corresponding to fixed DOFs) at $t=0$.

# %%
all_DOFs = np.arange(ndof) # Set of all DOFs
fixed_index = np.array([0, 1]) # Fixed DOFs

print("Fixed DOFs:", fixed_index)

# Free index
free_index = np.setdiff1d(all_DOFs, fixed_index) # All the DOFs are free except the fixed ones
# Out:
# Fixed DOFs: [0 1]

# %% [markdown]
# **Trajectory and Initial Conditions**

# %%
# Number of steps
Nsteps = round( totalTime / dt )
ctime = 0 # Current time

# Store the y-coordinate of the middle node, its velocity, and the angle
mid_pos = np.zeros((Nsteps, 2))

#Target Trajectory
t = np.arange(Nsteps) * dt
T = 1000 # second
mid_pos[:, 0] = (RodLength/2) * (np.cos((np.pi/2) * t / T)) # mid node x-coordinate trajectory
mid_pos[:, 1] = - (RodLength/2) * (np.sin((np.pi/2) * t / T)) # mid node y-coordinate trajectory

#print(mid_pos[int(200/dt),0])
#print(mid_pos[int(100/dt),1])

print(mid_pos[:,0])
print(mid_pos[:,1])

plt.plot(t, mid_pos[:, 0], 'ko-')
plt.title('Target Mid-node x Position')
plt.xlabel('x')
plt.ylabel('t')
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.show()

plt.plot(t, mid_pos[:, 1], 'ko-')
plt.title('Target Mid-node y Position')
plt.xlabel('y')
plt.ylabel('t')
plt.ylim(-1, 1)
plt.xlim(0, 1)
plt.show()

# Initial conditions
q0 = np.zeros(2 * nv)
for c in range(nv):
  q0[2*c] = nodes[c, 0] # x coordinate
  q0[2*c+1] = nodes[c, 1] # y coordinate
# q0[2*midNode-2] = mid_pos[0, 0] # mid node initial x position
# q0[2*midNode-1] = mid_pos[0, 1] # mid node initial y position
#print(q0)
u0 = np.zeros(2 * nv) # old velocity

control_state = np.zeros((Nsteps, 3)) # [x_c, y_c, theta_c]
control_state[0,0] = q0[2*controlNode-2]
control_state[0,1] = q0[2*controlNode-1]
control_state[0,2] = 0.0 # initial orientation
# Out:
# [0.5        0.5        0.49999999 0.49999999 0.49999998 0.49999996
#  0.49999994 0.49999992 0.4999999  0.49999988 0.49999985 0.49999981
#  0.49999978 0.49999974 0.4999997  0.49999965 0.49999961 0.49999955
#  0.4999995  0.49999944]
# [-0.00000000e+00 -3.92699081e-05 -7.85398160e-05 -1.17809723e-04
#  -1.57079630e-04 -1.96349536e-04 -2.35619440e-04 -2.74889343e-04
#  -3.14159245e-04 -3.53429144e-04 -3.92699041e-04 -4.31968936e-04
#  -4.71238828e-04 -5.10508718e-04 -5.49778604e-04 -5.89048486e-04
#  -6.28318365e-04 -6.67588241e-04 -7.06858112e-04 -7.46127978e-04]

# %% [markdown]
# **Time stepping loop**

# %%
# Loop over the time steps
for timeStep in range(1, Nsteps):
    # initial guess for control input
    control_state[timeStep] = control_state[timeStep - 1]

    for iter in range(40):
        # Solve equilibrium for current control state
        q_new, error = equilibrium_solver(
            q0, u0, dt, tol, maximum_iter,
            m, mMat, EI, EA, W, C, deltaL,
            free_index, control_state[timeStep], controlNode
        )

        if error < 0:
            print('Could not converge.')
            break

        mid_desired = mid_pos[timeStep]
        converged = False

        # Midpoint error
        mid_pos_current = q_new[2 * midNode - 2:2 * midNode]
        mid_error = mid_desired - mid_pos_current
        if np.linalg.norm(mid_error) < 1e-4:
            converged = True
            break

        # Compute numerical Jacobian wrt [x_c, y_c, theta_c]
        J = np.zeros((2, 3))
        eps = 1e-4
        for i in range(3):
            du = np.zeros(3)
            du[i] = eps
            q_pert, _ = equilibrium_solver(
                q0, u0, dt, tol, maximum_iter,
                m, mMat, EI, EA, W, C, deltaL,
                free_index, control_state[timeStep] + du, controlNode
            )

            mid_pert = q_pert[2 * midNode - 2:2 * midNode]
            J[:, i] = (mid_pert - mid_pos_current) / eps

        # Compute control update (least squares)
        du = np.linalg.pinv(J) @ mid_error
        du = np.clip(du, -4e-3, 4e-3)  # Limit the update size
        control_state[timeStep] += du  # update control node pose

        print(f"t={ctime:.4f}, Error={np.linalg.norm(mid_error):.3e}, iters={iter}", "du:", du)

    # After convergence or max iterations:
    u_new = (q_new - q0) / dt  # New velocity
    ctime += dt  # Update current time

    print('current time:', ctime)

    q0 = q_new.copy()  # New position becomes old position
    u0 = u_new.copy()  # New velocity becomes old velocity

    # Plot
    if timeStep % plotStep == 0 or ctime == 0 or round(ctime, 2) == 0.95:
        x_arr = q_new[::2]  # q[0], q[2], q[4]
        y_arr = q_new[1::2]  # q[1], q[3], q[5]

        plt.figure(1)
        plt.clf()  # Clear current figure
        plt.plot(x_arr, y_arr, 'k-', zorder=1)  # Plot main line (black)

        # Plot all nodes with conditional colors
        for i, (x, y) in enumerate(zip(x_arr, y_arr), start=1):
            if i == midNode:
                color = 'red'
            elif i == controlNode:
                color = 'blue'
            else:
                color = 'black'
            plt.plot(x, y, 'o', color=color, markersize=6, zorder=2)
            plt.text(x, y, str(i), fontsize=10, color=color,
                     ha='right', va='bottom')

        # Plot target mid-node position
        plt.plot(mid_pos[timeStep, 0], mid_pos[timeStep, 1], 'x', markersize=10, color='green', label='Target Mid-node', zorder=3)

        # Fixed-position text
        mid_x, mid_y = x_arr[midNode - 1], y_arr[midNode - 1]
        control_x, control_y = x_arr[controlNode - 1], y_arr[controlNode - 1]

        # Control angle in degrees (assuming it's the 3rd element of control_state)
        theta_c_rad = control_state[timeStep][2]  # adjust index if needed
        theta_c_deg = np.degrees(theta_c_rad)

        # Display Mid-node
        plt.text(0.02, 0.95, f'Mid-node {midNode}: ({mid_x:.6f}, {mid_y:.6f})',
                 transform=plt.gca().transAxes, color='red', fontsize=10,
                 bbox=dict(facecolor='white', alpha=0.6))

        # Display Control-node with angle
        plt.text(0.02, 0.85, f'Control-node {controlNode}: ({control_x:.6f}, {control_y:.6f}), θ={theta_c_deg:.4f}°',
                 transform=plt.gca().transAxes, color='blue', fontsize=10,
                 bbox=dict(facecolor='white', alpha=0.6))

        plt.title(f't={ctime:.4f}s')
        plt.xlabel('x')
        plt.ylabel('y')
        plt.ylim([-0.05, 0.05])
        plt.legend()
        plt.show()
# Out:
# Control Node Position: x = 1.0000, y = 0.0000. Orientation: theta = 0.0000 rad
# Control Node Position: x = 1.0001, y = 0.0000. Orientation: theta = 0.0000 rad
# Control Node Position: x = 1.0000, y = 0.0001. Orientation: theta = 0.0000 rad
# Control Node Position: x = 1.0000, y = 0.0000. Orientation: theta = 0.0001 rad
# t=0.0000, Error=2.035e-02, iters=0 du: [-0.004       0.004      -0.00082618]
# Control Node Position: x = 0.9960, y = 0.0040. Orientation: theta = -0.0008 rad
# Control Node Position: x = 0.9961, y = 0.0040. Orientation: theta = -0.0008 rad
# Control Node Position: x = 0.9960, y = 0.0041. Orientation: theta = -0.0008 rad
# Control Node Position: x = 0.9960, y = 0.0040. Orientation: theta = -0.0007 rad
# t=0.0000, Error=1.983e-02, iters=1 du: [-0.004       0.004      -0.00016117]
# Control Node Position: x = 0.9920, y = 0.0080. Orientation: theta = -0.0010 rad
# Control Node Position: x = 0.9921, y = 0.0080. Orientation: theta = -0.0010 rad
# Control Node Position: x = 0.9920, y = 0.0081. Orientation: theta = -0.0010 rad
# Control Node Position: x = 0.9920, y = 0.0080. Orientation: theta = -0.0009 rad
# t=0.0000, Error=1.930e-02, iters=2 du: [-0.004       0.004      -0.00032147]
# Control Node Position: x = 0.9880, y = 0.0120. Orientation: theta = -0.0013 rad
# Control Node Position: x = 0.9881, y = 0.0120. Orientation: theta = -0.0013 rad
# Control Node Position: x = 0.9880, y = 0.0121. Orientation: theta = -0.0013 rad
# Control Node Position: x = 0.9880, y = 0.0120. Orientation: theta = -0.0012 rad
# t=0.0000, Error=1.878e-02, iters=3 du: [-0.004       0.004       0.00052121]
# Control Node Position: x = 0.9840, y = 0.0160. Orientation: theta = -0.0008 rad
# Control Node Position: x = 0.9841, y = 0.0160. Orientation: theta = -0.0008 rad
# Control Node Position: x = 0.9840, y = 0.0161. Orientation: theta = -0.0008 rad
# Control Node Position: x = 0.9840, y = 0.0160. Orientation: theta = -0.0007 rad
# t=0.0000, Error=1.825e-02, iters=4 du: [-0.004       0.004       0.00068083]
# Control Node Position: x = 0.9800, y = 0.0200. Orientation: theta = -0.0001 rad
# Control Node Position: x = 0.9801, y = 0.0200. Orientation: theta = -0.0001 rad
# Control Node Position: x = 0.9800, y = 0.0201. Orientation: theta = -0.0001 rad
# Control Node Position: x = 0.9800, y = 0.0200. Orientation: theta = -0.0000 rad
# t=0.0000, Error=1.773e-02, iters=5 du: [-0.004       0.004       0.00079024]
# Control Node Position: x = 0.9760, y = 0.0240. Orientation: theta = 0.0007 rad
# Control Node Position: x = 0.9761, y = 0.0240. Orientation: theta = 0.0007 rad
# Control Node Position: x = 0.9760, y = 0.0241. Orientation: theta = 0.0007 rad
# Control Node Position: x = 0.9760, y = 0.0240. Orientation: theta = 0.0008 rad
# t=0.0000, Error=1.720e-02, iters=6 du: [-0.004       0.004       0.00086169]
# Control Node Position: x = 0.9720, y = 0.0280. Orientation: theta = 0.0015 rad
# Control Node Position: x = 0.9721, y = 0.0280. Orientation: theta = 0.0015 rad
# Control Node Position: x = 0.9720, y = 0.0281. Orientation: theta = 0.0015 rad
# Control Node Position: x = 0.9720, y = 0.0280. Orientation: theta = 0.0016 rad
# t=0.0000, Error=1.668e-02, iters=7 du: [-0.004       0.004       0.00097808]
# Control Node Position: x = 0.9680, y = 0.0320. Orientation: theta = 0.0025 rad
# Control Node Position: x = 0.9681, y = 0.0320. Orientation: theta = 0.0025 rad
# Control Node Position: x = 0.9680, y = 0.0321. Orientation: theta = 0.0025 rad
# Control Node Position: x = 0.9680, y = 0.0320. Orientation: theta = 0.0026 rad
# t=0.0000, Error=1.615e-02, iters=8 du: [-0.004       0.004       0.00091417]
# Control Node Position: x = 0.9640, y = 0.0360. Orientation: theta = 0.0034 rad
# Control Node Position: x = 0.9641, y = 0.0360. Orientation: theta = 0.0034 rad
# Control Node Position: x = 0.9640, y = 0.0361. Orientation: theta = 0.0034 rad
# Control Node Position: x = 0.9640, y = 0.0360. Orientation: theta = 0.0035 rad
# t=0.0000, Error=1.562e-02, iters=9 du: [-0.004       0.004       0.00091648]
# Control Node Position: x = 0.9600, y = 0.0400. Orientation: theta = 0.0044 rad
# Control Node Position: x = 0.9601, y = 0.0400. Orientation: theta = 0.0044 rad
# Control Node Position: x = 0.9600, y = 0.0401. Orientation: theta = 0.0044 rad
# Control Node Position: x = 0.9600, y = 0.0400. Orientation: theta = 0.0045 rad
# t=0.0000, Error=1.509e-02, iters=10 du: [-0.004      0.004      0.0009035]
# Control Node Position: x = 0.9560, y = 0.0440. Orientation: theta = 0.0053 rad
# Control Node Position: x = 0.9561, y = 0.0440. Orientation: theta = 0.0053 rad
# Control Node Position: x = 0.9560, y = 0.0441. Orientation: theta = 0.0053 rad
# Control Node Position: x = 0.9560, y = 0.0440. Orientation: theta = 0.0054 rad
# t=0.0000, Error=1.456e-02, iters=11 du: [-0.004       0.004       0.00087697]
# Control Node Position: x = 0.9520, y = 0.0480. Orientation: theta = 0.0061 rad
# Control Node Position: x = 0.9521, y = 0.0480. Orientation: theta = 0.0061 rad
# Control Node Position: x = 0.9520, y = 0.0481. Orientation: theta = 0.0061 rad
# Control Node Position: x = 0.9520, y = 0.0480. Orientation: theta = 0.0062 rad
# t=0.0000, Error=1.403e-02, iters=12 du: [-0.004      0.004      0.0006887]
# Control Node Position: x = 0.9480, y = 0.0520. Orientation: theta = 0.0068 rad
# Control Node Position: x = 0.9481, y = 0.0520. Orientation: theta = 0.0068 rad
# Control Node Position: x = 0.9480, y = 0.0521. Orientation: theta = 0.0068 rad
# Control Node Position: x = 0.9480, y = 0.0520. Orientation: theta = 0.0069 rad
# t=0.0000, Error=1.349e-02, iters=13 du: [-0.004       0.004       0.00080684]
# Control Node Position: x = 0.9440, y = 0.0560. Orientation: theta = 0.0076 rad
# Control Node Position: x = 0.9441, y = 0.0560. Orientation: theta = 0.0076 rad
# Control Node Position: x = 0.9440, y = 0.0561. Orientation: theta = 0.0076 rad
# Control Node Position: x = 0.9440, y = 0.0560. Orientation: theta = 0.0077 rad
# t=0.0000, Error=1.296e-02, iters=14 du: [-0.004       0.004       0.00282751]
# Control Node Position: x = 0.9400, y = 0.0600. Orientation: theta = 0.0105 rad
# Control Node Position: x = 0.9401, y = 0.0600. Orientation: theta = 0.0105 rad
# Control Node Position: x = 0.9400, y = 0.0601. Orientation: theta = 0.0105 rad
# Control Node Position: x = 0.9400, y = 0.0600. Orientation: theta = 0.0106 rad
# t=0.0000, Error=1.243e-02, iters=15 du: [-0.004       0.004       0.00055057]
# Control Node Position: x = 0.9360, y = 0.0640. Orientation: theta = 0.0110 rad
# Control Node Position: x = 0.9361, y = 0.0640. Orientation: theta = 0.0110 rad
# Control Node Position: x = 0.9360, y = 0.0641. Orientation: theta = 0.0110 rad
# Control Node Position: x = 0.9360, y = 0.0640. Orientation: theta = 0.0111 rad
# t=0.0000, Error=9.994e-01, iters=16 du: [-0.004  0.004  0.004]
# Control Node Position: x = 0.9320, y = 0.0680. Orientation: theta = 0.0150 rad
# Control Node Position: x = 0.9321, y = 0.0680. Orientation: theta = 0.0150 rad
# Control Node Position: x = 0.9320, y = 0.0681. Orientation: theta = 0.0150 rad
# Control Node Position: x = 0.9320, y = 0.0680. Orientation: theta = 0.0151 rad
# t=0.0000, Error=1.136e-02, iters=17 du: [-0.004       0.004      -0.00014804]
# Control Node Position: x = 0.9280, y = 0.0720. Orientation: theta = 0.0149 rad
# Control Node Position: x = 0.9281, y = 0.0720. Orientation: theta = 0.0149 rad
# Control Node Position: x = 0.9280, y = 0.0721. Orientation: theta = 0.0149 rad
# Control Node Position: x = 0.9280, y = 0.0720. Orientation: theta = 0.0150 rad
# t=0.0000, Error=1.081e-02, iters=18 du: [-0.004  0.004  0.004]
# Control Node Position: x = 0.9240, y = 0.0760. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9241, y = 0.0760. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9240, y = 0.0761. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9240, y = 0.0760. Orientation: theta = 0.0190 rad
# t=0.0000, Error=1.028e-02, iters=19 du: [-4.00000000e-03  4.00000000e-03  2.59738108e-05]
# Control Node Position: x = 0.9200, y = 0.0800. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9201, y = 0.0800. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9200, y = 0.0801. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9200, y = 0.0800. Orientation: theta = 0.0190 rad
# t=0.0000, Error=9.736e-03, iters=20 du: [-4.00000000e-03  4.00000000e-03 -7.86264124e-06]
# Control Node Position: x = 0.9160, y = 0.0840. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9161, y = 0.0840. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9160, y = 0.0841. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9160, y = 0.0840. Orientation: theta = 0.0190 rad
# t=0.0000, Error=9.188e-03, iters=21 du: [-4.00000000e-03  4.00000000e-03  5.32237063e-05]
# Control Node Position: x = 0.9120, y = 0.0880. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9121, y = 0.0880. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9120, y = 0.0881. Orientation: theta = 0.0189 rad
# Control Node Position: x = 0.9120, y = 0.0880. Orientation: theta = 0.0190 rad
# t=0.0000, Error=8.638e-03, iters=22 du: [-0.004       0.004      -0.00011091]
# Control Node Position: x = 0.9080, y = 0.0920. Orientation: theta = 0.0188 rad
# Control Node Position: x = 0.9081, y = 0.0920. Orientation: theta = 0.0188 rad
# Control Node Position: x = 0.9080, y = 0.0921. Orientation: theta = 0.0188 rad
# Control Node Position: x = 0.9080, y = 0.0920. Orientation: theta = 0.0189 rad
# t=0.0000, Error=8.087e-03, iters=23 du: [-0.004       0.004      -0.00017728]
# Control Node Position: x = 0.9040, y = 0.0960. Orientation: theta = 0.0186 rad
# Control Node Position: x = 0.9041, y = 0.0960. Orientation: theta = 0.0186 rad
# Control Node Position: x = 0.9040, y = 0.0961. Orientation: theta = 0.0186 rad
# Control Node Position: x = 0.9040, y = 0.0960. Orientation: theta = 0.0187 rad
# t=0.0000, Error=7.533e-03, iters=24 du: [-0.004       0.004      -0.00024112]
# Control Node Position: x = 0.9000, y = 0.1000. Orientation: theta = 0.0184 rad
# Control Node Position: x = 0.9001, y = 0.1000. Orientation: theta = 0.0184 rad
# Control Node Position: x = 0.9000, y = 0.1001. Orientation: theta = 0.0184 rad
# Control Node Position: x = 0.9000, y = 0.1000. Orientation: theta = 0.0185 rad
# t=0.0000, Error=6.978e-03, iters=25 du: [-0.004       0.004      -0.00031031]
# Control Node Position: x = 0.8960, y = 0.1040. Orientation: theta = 0.0181 rad
# Control Node Position: x = 0.8961, y = 0.1040. Orientation: theta = 0.0181 rad
# Control Node Position: x = 0.8960, y = 0.1041. Orientation: theta = 0.0181 rad
# Control Node Position: x = 0.8960, y = 0.1040. Orientation: theta = 0.0182 rad
# t=0.0000, Error=6.421e-03, iters=26 du: [-0.004      0.004     -0.0003843]
# Control Node Position: x = 0.8920, y = 0.1080. Orientation: theta = 0.0177 rad
# Control Node Position: x = 0.8921, y = 0.1080. Orientation: theta = 0.0177 rad
# Control Node Position: x = 0.8920, y = 0.1081. Orientation: theta = 0.0177 rad
# Control Node Position: x = 0.8920, y = 0.1080. Orientation: theta = 0.0178 rad
# t=0.0000, Error=5.863e-03, iters=27 du: [-0.004       0.004      -0.00045899]
# Control Node Position: x = 0.8880, y = 0.1120. Orientation: theta = 0.0172 rad
# Control Node Position: x = 0.8881, y = 0.1120. Orientation: theta = 0.0172 rad
# Control Node Position: x = 0.8880, y = 0.1121. Orientation: theta = 0.0172 rad
# Control Node Position: x = 0.8880, y = 0.1120. Orientation: theta = 0.0173 rad
# t=0.0000, Error=5.303e-03, iters=28 du: [-0.004       0.004      -0.00053245]
# Control Node Position: x = 0.8840, y = 0.1160. Orientation: theta = 0.0167 rad
# Control Node Position: x = 0.8841, y = 0.1160. Orientation: theta = 0.0167 rad
# Control Node Position: x = 0.8840, y = 0.1161. Orientation: theta = 0.0167 rad
# Control Node Position: x = 0.8840, y = 0.1160. Orientation: theta = 0.0168 rad
# t=0.0000, Error=4.741e-03, iters=29 du: [-0.004       0.004      -0.00060263]
# Control Node Position: x = 0.8800, y = 0.1200. Orientation: theta = 0.0161 rad
# Control Node Position: x = 0.8801, y = 0.1200. Orientation: theta = 0.0161 rad
# Control Node Position: x = 0.8800, y = 0.1201. Orientation: theta = 0.0161 rad
# Control Node Position: x = 0.8800, y = 0.1200. Orientation: theta = 0.0162 rad
# t=0.0000, Error=9.992e-01, iters=30 du: [ 0.00010002 -0.004       0.00047778]
# Control Node Position: x = 0.8801, y = 0.1160. Orientation: theta = 0.0166 rad
# Control Node Position: x = 0.8802, y = 0.1160. Orientation: theta = 0.0166 rad
# Control Node Position: x = 0.8801, y = 0.1161. Orientation: theta = 0.0166 rad
# Control Node Position: x = 0.8801, y = 0.1160. Orientation: theta = 0.0167 rad
# t=0.0000, Error=9.992e-01, iters=31 du: [ 0.004 -0.004  0.004]
# Control Node Position: x = 0.8841, y = 0.1120. Orientation: theta = 0.0206 rad
# Control Node Position: x = 0.8842, y = 0.1120. Orientation: theta = 0.0206 rad
# Control Node Position: x = 0.8841, y = 0.1121. Orientation: theta = 0.0206 rad
# Control Node Position: x = 0.8841, y = 0.1120. Orientation: theta = 0.0207 rad
# t=0.0000, Error=5.319e-03, iters=32 du: [-0.004       0.004      -0.00060725]
# Control Node Position: x = 0.8801, y = 0.1160. Orientation: theta = 0.0200 rad
# Control Node Position: x = 0.8802, y = 0.1160. Orientation: theta = 0.0200 rad
# Control Node Position: x = 0.8801, y = 0.1161. Orientation: theta = 0.0200 rad
# Control Node Position: x = 0.8801, y = 0.1160. Orientation: theta = 0.0201 rad
# t=0.0000, Error=9.992e-01, iters=33 du: [ 0.004 -0.004  0.004]
# Control Node Position: x = 0.8841, y = 0.1120. Orientation: theta = 0.0240 rad
# Control Node Position: x = 0.8842, y = 0.1120. Orientation: theta = 0.0240 rad
# Control Node Position: x = 0.8841, y = 0.1121. Orientation: theta = 0.0240 rad
# Control Node Position: x = 0.8841, y = 0.1120. Orientation: theta = 0.0241 rad
# t=0.0000, Error=5.332e-03, iters=34 du: [-0.004       0.004      -0.00124936]
# Control Node Position: x = 0.8801, y = 0.1160. Orientation: theta = 0.0227 rad
# Control Node Position: x = 0.8802, y = 0.1160. Orientation: theta = 0.0227 rad
# Control Node Position: x = 0.8801, y = 0.1161. Orientation: theta = 0.0227 rad
# Control Node Position: x = 0.8801, y = 0.1160. Orientation: theta = 0.0228 rad
# t=0.0000, Error=9.992e-01, iters=35 du: [ 0.004 -0.004  0.004]
# Control Node Position: x = 0.8841, y = 0.1120. Orientation: theta = 0.0267 rad
# Control Node Position: x = 0.8842, y = 0.1120. Orientation: theta = 0.0267 rad
# Control Node Position: x = 0.8841, y = 0.1121. Orientation: theta = 0.0267 rad
# Control Node Position: x = 0.8841, y = 0.1120. Orientation: theta = 0.0268 rad
# t=0.0000, Error=5.342e-03, iters=36 du: [-0.004       0.004      -0.00047532]
# Control Node Position: x = 0.8801, y = 0.1160. Orientation: theta = 0.0263 rad
# Control Node Position: x = 0.8802, y = 0.1160. Orientation: theta = 0.0263 rad
# Control Node Position: x = 0.8801, y = 0.1161. Orientation: theta = 0.0263 rad
# Control Node Position: x = 0.8801, y = 0.1160. Orientation: theta = 0.0264 rad
# t=0.0000, Error=4.780e-03, iters=37 du: [-0.004       0.004      -0.00064467]
# Control Node Position: x = 0.8761, y = 0.1200. Orientation: theta = 0.0256 rad
# Control Node Position: x = 0.8762, y = 0.1200. Orientation: theta = 0.0256 rad
# Control Node Position: x = 0.8761, y = 0.1201. Orientation: theta = 0.0256 rad
# Control Node Position: x = 0.8761, y = 0.1200. Orientation: theta = 0.0257 rad
# t=0.0000, Error=4.216e-03, iters=38 du: [-0.004       0.004      -0.00068795]
# Control Node Position: x = 0.8721, y = 0.1240. Orientation: theta = 0.0249 rad
# Control Node Position: x = 0.8722, y = 0.1240. Orientation: theta = 0.0249 rad
# Control Node Position: x = 0.8721, y = 0.1241. Orientation: theta = 0.0249 rad
# Control Node Position: x = 0.8721, y = 0.1240. Orientation: theta = 0.0250 rad
# t=0.0000, Error=3.650e-03, iters=39 du: [ 0.004       0.004      -0.00072622]
# current time: 0.05
# Control Node Position: x = 0.8761, y = 0.1280. Orientation: theta = 0.0242 rad
# Control Node Position: x = 0.8762, y = 0.1280. Orientation: theta = 0.0242 rad
# Control Node Position: x = 0.8761, y = 0.1281. Orientation: theta = 0.0242 rad
# Control Node Position: x = 0.8761, y = 0.1280. Orientation: theta = 0.0243 rad
# t=0.0500, Error=5.999e-03, iters=0 du: [-0.004      0.004     -0.0004792]
# Control Node Position: x = 0.8721, y = 0.1320. Orientation: theta = 0.0237 rad
# Control Node Position: x = 0.8722, y = 0.1320. Orientation: theta = 0.0237 rad
# Control Node Position: x = 0.8721, y = 0.1321. Orientation: theta = 0.0237 rad
# Control Node Position: x = 0.8721, y = 0.1320. Orientation: theta = 0.0238 rad
# t=0.0500, Error=9.991e-01, iters=1 du: [-0.004       0.004       0.00324293]
# Control Node Position: x = 0.8681, y = 0.1360. Orientation: theta = 0.0270 rad
# Control Node Position: x = 0.8682, y = 0.1360. Orientation: theta = 0.0270 rad
# Control Node Position: x = 0.8681, y = 0.1361. Orientation: theta = 0.0270 rad
# Control Node Position: x = 0.8681, y = 0.1360. Orientation: theta = 0.0271 rad
# t=0.0500, Error=4.885e-03, iters=2 du: [-0.004       0.004      -0.00070084]
# Control Node Position: x = 0.8641, y = 0.1400. Orientation: theta = 0.0263 rad
# Control Node Position: x = 0.8642, y = 0.1400. Orientation: theta = 0.0263 rad
# Control Node Position: x = 0.8641, y = 0.1401. Orientation: theta = 0.0263 rad
# Control Node Position: x = 0.8641, y = 0.1400. Orientation: theta = 0.0264 rad
# t=0.0500, Error=4.318e-03, iters=3 du: [-0.004       0.004      -0.00078973]
# Control Node Position: x = 0.8601, y = 0.1440. Orientation: theta = 0.0255 rad
# Control Node Position: x = 0.8602, y = 0.1440. Orientation: theta = 0.0255 rad
# Control Node Position: x = 0.8601, y = 0.1441. Orientation: theta = 0.0255 rad
# Control Node Position: x = 0.8601, y = 0.1440. Orientation: theta = 0.0256 rad
# t=0.0500, Error=3.749e-03, iters=4 du: [ 0.004       0.004      -0.00086496]
# Control Node Position: x = 0.8641, y = 0.1480. Orientation: theta = 0.0246 rad
# Control Node Position: x = 0.8642, y = 0.1480. Orientation: theta = 0.0246 rad
# Control Node Position: x = 0.8641, y = 0.1481. Orientation: theta = 0.0246 rad
# Control Node Position: x = 0.8641, y = 0.1480. Orientation: theta = 0.0247 rad
# t=0.0500, Error=3.179e-03, iters=5 du: [ 0.004       0.004      -0.00091108]
# Control Node Position: x = 0.8681, y = 0.1520. Orientation: theta = 0.0237 rad
# Control Node Position: x = 0.8682, y = 0.1520. Orientation: theta = 0.0237 rad
# Control Node Position: x = 0.8681, y = 0.1521. Orientation: theta = 0.0237 rad
# Control Node Position: x = 0.8681, y = 0.1520. Orientation: theta = 0.0238 rad
# t=0.0500, Error=2.610e-03, iters=6 du: [ 0.004       0.004      -0.00093956]
# Control Node Position: x = 0.8721, y = 0.1560. Orientation: theta = 0.0228 rad
# Control Node Position: x = 0.8722, y = 0.1560. Orientation: theta = 0.0228 rad
# Control Node Position: x = 0.8721, y = 0.1561. Orientation: theta = 0.0228 rad
# Control Node Position: x = 0.8721, y = 0.1560. Orientation: theta = 0.0229 rad
# t=0.0500, Error=2.043e-03, iters=7 du: [ 0.004       0.004      -0.00092755]
# Control Node Position: x = 0.8761, y = 0.1600. Orientation: theta = 0.0218 rad
# Control Node Position: x = 0.8762, y = 0.1600. Orientation: theta = 0.0218 rad
# Control Node Position: x = 0.8761, y = 0.1601. Orientation: theta = 0.0218 rad
# Control Node Position: x = 0.8761, y = 0.1600. Orientation: theta = 0.0219 rad
# t=0.0500, Error=1.477e-03, iters=8 du: [ 0.004       0.004      -0.00093352]
# Control Node Position: x = 0.8801, y = 0.1640. Orientation: theta = 0.0209 rad
# Control Node Position: x = 0.8802, y = 0.1640. Orientation: theta = 0.0209 rad
# Control Node Position: x = 0.8801, y = 0.1641. Orientation: theta = 0.0209 rad
# Control Node Position: x = 0.8801, y = 0.1640. Orientation: theta = 0.0210 rad
# t=0.0500, Error=9.132e-04, iters=9 du: [ 0.004     0.004    -0.000894]
# Control Node Position: x = 0.8841, y = 0.1680. Orientation: theta = 0.0200 rad
# Control Node Position: x = 0.8842, y = 0.1680. Orientation: theta = 0.0200 rad
# Control Node Position: x = 0.8841, y = 0.1681. Orientation: theta = 0.0200 rad
# Control Node Position: x = 0.8841, y = 0.1680. Orientation: theta = 0.0201 rad
# t=0.0500, Error=3.507e-04, iters=10 du: [ 0.004       0.004      -0.00082673]
# Control Node Position: x = 0.8881, y = 0.1720. Orientation: theta = 0.0192 rad
# Control Node Position: x = 0.8882, y = 0.1720. Orientation: theta = 0.0192 rad
# Control Node Position: x = 0.8881, y = 0.1721. Orientation: theta = 0.0192 rad
# Control Node Position: x = 0.8881, y = 0.1720. Orientation: theta = 0.0193 rad
# t=0.0500, Error=2.114e-04, iters=11 du: [ 0.004       0.00059711 -0.00071364]
# Control Node Position: x = 0.8921, y = 0.1726. Orientation: theta = 0.0185 rad
# Control Node Position: x = 0.8922, y = 0.1726. Orientation: theta = 0.0185 rad
# Control Node Position: x = 0.8921, y = 0.1727. Orientation: theta = 0.0185 rad
# Control Node Position: x = 0.8921, y = 0.1726. Orientation: theta = 0.0186 rad
# t=0.0500, Error=2.929e-04, iters=12 du: [ 4.00000000e-03  3.91849507e-05 -7.04823081e-04]
# Control Node Position: x = 0.8961, y = 0.1726. Orientation: theta = 0.0178 rad
# Control Node Position: x = 0.8962, y = 0.1726. Orientation: theta = 0.0178 rad
# Control Node Position: x = 0.8961, y = 0.1727. Orientation: theta = 0.0178 rad
# Control Node Position: x = 0.8961, y = 0.1726. Orientation: theta = 0.0179 rad
# t=0.0500, Error=2.963e-04, iters=13 du: [ 4.00000000e-03 -2.25322421e-05 -6.95195570e-04]
# Control Node Position: x = 0.9001, y = 0.1726. Orientation: theta = 0.0171 rad
# Control Node Position: x = 0.9002, y = 0.1726. Orientation: theta = 0.0171 rad
# Control Node Position: x = 0.9001, y = 0.1727. Orientation: theta = 0.0171 rad
# Control Node Position: x = 0.9001, y = 0.1726. Orientation: theta = 0.0172 rad
# t=0.0500, Error=2.910e-04, iters=14 du: [ 4.00000000e-03 -2.62423344e-05 -6.87125301e-04]
# Control Node Position: x = 0.9041, y = 0.1726. Orientation: theta = 0.0164 rad
# Control Node Position: x = 0.9042, y = 0.1726. Orientation: theta = 0.0164 rad
# Control Node Position: x = 0.9041, y = 0.1727. Orientation: theta = 0.0164 rad
# Control Node Position: x = 0.9041, y = 0.1726. Orientation: theta = 0.0165 rad
# t=0.0500, Error=2.851e-04, iters=15 du: [ 4.00000000e-03 -2.61287711e-05 -6.79002387e-04]
# Control Node Position: x = 0.9081, y = 0.1726. Orientation: theta = 0.0157 rad
# Control Node Position: x = 0.9082, y = 0.1726. Orientation: theta = 0.0157 rad
# Control Node Position: x = 0.9081, y = 0.1727. Orientation: theta = 0.0157 rad
# Control Node Position: x = 0.9081, y = 0.1726. Orientation: theta = 0.0158 rad
# t=0.0500, Error=2.793e-04, iters=16 du: [ 4.00000000e-03 -2.06547057e-05 -1.07209061e-03]
# Control Node Position: x = 0.9121, y = 0.1725. Orientation: theta = 0.0146 rad
# Control Node Position: x = 0.9122, y = 0.1725. Orientation: theta = 0.0146 rad
# Control Node Position: x = 0.9121, y = 0.1726. Orientation: theta = 0.0146 rad
# Control Node Position: x = 0.9121, y = 0.1725. Orientation: theta = 0.0147 rad
# t=0.0500, Error=2.757e-04, iters=17 du: [ 4.00000000e-03 -4.05401648e-05 -6.64409831e-04]
# Control Node Position: x = 0.9161, y = 0.1725. Orientation: theta = 0.0140 rad
# Control Node Position: x = 0.9162, y = 0.1725. Orientation: theta = 0.0140 rad
# Control Node Position: x = 0.9161, y = 0.1726. Orientation: theta = 0.0140 rad
# Control Node Position: x = 0.9161, y = 0.1725. Orientation: theta = 0.0141 rad
# t=0.0500, Error=2.678e-04, iters=18 du: [ 4.00000000e-03 -2.59705235e-05 -6.56224206e-04]
# Control Node Position: x = 0.9201, y = 0.1725. Orientation: theta = 0.0133 rad
# Control Node Position: x = 0.9202, y = 0.1725. Orientation: theta = 0.0133 rad
# Control Node Position: x = 0.9201, y = 0.1726. Orientation: theta = 0.0133 rad
# Control Node Position: x = 0.9201, y = 0.1725. Orientation: theta = 0.0134 rad
# t=0.0500, Error=2.620e-04, iters=19 du: [ 4.00000000e-03 -2.46814355e-05 -6.48346937e-04]
# Control Node Position: x = 0.9241, y = 0.1724. Orientation: theta = 0.0127 rad
# Control Node Position: x = 0.9242, y = 0.1724. Orientation: theta = 0.0127 rad
# Control Node Position: x = 0.9241, y = 0.1725. Orientation: theta = 0.0127 rad
# Control Node Position: x = 0.9241, y = 0.1724. Orientation: theta = 0.0128 rad
# t=0.0500, Error=2.563e-04, iters=20 du: [ 4.00000000e-03 -2.43414422e-05 -6.38594216e-04]
# Control Node Position: x = 0.9281, y = 0.1724. Orientation: theta = 0.0120 rad
# Control Node Position: x = 0.9282, y = 0.1724. Orientation: theta = 0.0120 rad
# Control Node Position: x = 0.9281, y = 0.1725. Orientation: theta = 0.0120 rad
# Control Node Position: x = 0.9281, y = 0.1724. Orientation: theta = 0.0121 rad
# t=0.0500, Error=2.506e-04, iters=21 du: [ 4.00000000e-03 -2.38825593e-05 -6.29542874e-04]
# Control Node Position: x = 0.9321, y = 0.1724. Orientation: theta = 0.0114 rad
# Control Node Position: x = 0.9322, y = 0.1724. Orientation: theta = 0.0114 rad
# Control Node Position: x = 0.9321, y = 0.1725. Orientation: theta = 0.0114 rad
# Control Node Position: x = 0.9321, y = 0.1724. Orientation: theta = 0.0115 rad
# t=0.0500, Error=2.450e-04, iters=22 du: [ 4.00000000e-03 -2.34786433e-05 -6.20342797e-04]
# Control Node Position: x = 0.9361, y = 0.1724. Orientation: theta = 0.0108 rad
# Control Node Position: x = 0.9362, y = 0.1724. Orientation: theta = 0.0108 rad
# Control Node Position: x = 0.9361, y = 0.1725. Orientation: theta = 0.0108 rad
# Control Node Position: x = 0.9361, y = 0.1724. Orientation: theta = 0.0109 rad
# t=0.0500, Error=2.395e-04, iters=23 du: [ 4.00000000e-03 -2.30752580e-05 -6.10999195e-04]
# Control Node Position: x = 0.9401, y = 0.1724. Orientation: theta = 0.0102 rad
# Control Node Position: x = 0.9402, y = 0.1724. Orientation: theta = 0.0102 rad
# Control Node Position: x = 0.9401, y = 0.1725. Orientation: theta = 0.0102 rad
# Control Node Position: x = 0.9401, y = 0.1724. Orientation: theta = 0.0103 rad
# t=0.0500, Error=2.340e-04, iters=24 du: [ 4.00000000e-03 -2.26692299e-05 -6.01512298e-04]
# Control Node Position: x = 0.9441, y = 0.1723. Orientation: theta = 0.0096 rad
# Control Node Position: x = 0.9442, y = 0.1723. Orientation: theta = 0.0096 rad
# Control Node Position: x = 0.9441, y = 0.1724. Orientation: theta = 0.0096 rad
# Control Node Position: x = 0.9441, y = 0.1723. Orientation: theta = 0.0097 rad
# t=0.0500, Error=2.285e-04, iters=25 du: [ 4.00000000e-03 -2.22604565e-05 -5.91886015e-04]
# Control Node Position: x = 0.9481, y = 0.1723. Orientation: theta = 0.0090 rad
# Control Node Position: x = 0.9482, y = 0.1723. Orientation: theta = 0.0090 rad
# Control Node Position: x = 0.9481, y = 0.1724. Orientation: theta = 0.0090 rad
# Control Node Position: x = 0.9481, y = 0.1723. Orientation: theta = 0.0091 rad
# t=0.0500, Error=2.231e-04, iters=26 du: [ 4.00000000e-03 -2.18490742e-05 -5.82123343e-04]
# Control Node Position: x = 0.9521, y = 0.1723. Orientation: theta = 0.0084 rad
# Control Node Position: x = 0.9522, y = 0.1723. Orientation: theta = 0.0084 rad
# Control Node Position: x = 0.9521, y = 0.1724. Orientation: theta = 0.0084 rad
# Control Node Position: x = 0.9521, y = 0.1723. Orientation: theta = 0.0085 rad
# t=0.0500, Error=2.177e-04, iters=27 du: [ 4.00000000e-03 -2.14349533e-05 -5.72223790e-04]
# Control Node Position: x = 0.9561, y = 0.1723. Orientation: theta = 0.0078 rad
# Control Node Position: x = 0.9562, y = 0.1723. Orientation: theta = 0.0078 rad
# Control Node Position: x = 0.9561, y = 0.1724. Orientation: theta = 0.0078 rad
# Control Node Position: x = 0.9561, y = 0.1723. Orientation: theta = 0.0079 rad
# t=0.0500, Error=2.123e-04, iters=28 du: [ 4.00000000e-03 -2.09031645e-05 -5.63453484e-04]
# Control Node Position: x = 0.9601, y = 0.1722. Orientation: theta = 0.0072 rad
# Control Node Position: x = 0.9602, y = 0.1722. Orientation: theta = 0.0072 rad
# Control Node Position: x = 0.9601, y = 0.1723. Orientation: theta = 0.0072 rad
# Control Node Position: x = 0.9601, y = 0.1722. Orientation: theta = 0.0073 rad
# t=0.0500, Error=2.070e-04, iters=29 du: [ 4.00000000e-03 -2.07004619e-05 -5.52375249e-04]
# Control Node Position: x = 0.9641, y = 0.1722. Orientation: theta = 0.0067 rad
# Control Node Position: x = 0.9642, y = 0.1722. Orientation: theta = 0.0067 rad
# Control Node Position: x = 0.9641, y = 0.1723. Orientation: theta = 0.0067 rad
# Control Node Position: x = 0.9641, y = 0.1722. Orientation: theta = 0.0068 rad
# t=0.0500, Error=2.017e-04, iters=30 du: [ 4.00000000e-03 -2.02164173e-05 -5.41805059e-04]
# Control Node Position: x = 0.9681, y = 0.1722. Orientation: theta = 0.0062 rad
# Control Node Position: x = 0.9682, y = 0.1722. Orientation: theta = 0.0062 rad
# Control Node Position: x = 0.9681, y = 0.1723. Orientation: theta = 0.0062 rad
# Control Node Position: x = 0.9681, y = 0.1722. Orientation: theta = 0.0063 rad
# t=0.0500, Error=1.964e-04, iters=31 du: [ 4.00000000e-03 -1.97660346e-05 -5.31286338e-04]
# Control Node Position: x = 0.9721, y = 0.1722. Orientation: theta = 0.0056 rad
# Control Node Position: x = 0.9722, y = 0.1722. Orientation: theta = 0.0056 rad
# Control Node Position: x = 0.9721, y = 0.1723. Orientation: theta = 0.0056 rad
# Control Node Position: x = 0.9721, y = 0.1722. Orientation: theta = 0.0057 rad
# t=0.0500, Error=1.912e-04, iters=32 du: [ 4.00000000e-03 -1.93306077e-05 -5.20679012e-04]
# Control Node Position: x = 0.9761, y = 0.1722. Orientation: theta = 0.0051 rad
# Control Node Position: x = 0.9762, y = 0.1722. Orientation: theta = 0.0051 rad
# Control Node Position: x = 0.9761, y = 0.1723. Orientation: theta = 0.0051 rad
# Control Node Position: x = 0.9761, y = 0.1722. Orientation: theta = 0.0052 rad
# t=0.0500, Error=1.861e-04, iters=33 du: [ 4.00000000e-03 -1.88989959e-05 -5.09915544e-04]
# Control Node Position: x = 0.9801, y = 0.1721. Orientation: theta = 0.0046 rad
# Control Node Position: x = 0.9802, y = 0.1721. Orientation: theta = 0.0046 rad
# Control Node Position: x = 0.9801, y = 0.1722. Orientation: theta = 0.0046 rad
# Control Node Position: x = 0.9801, y = 0.1721. Orientation: theta = 0.0047 rad
# t=0.0500, Error=1.809e-04, iters=34 du: [ 4.00000000e-03 -1.84692608e-05 -4.98856714e-04]
# Control Node Position: x = 0.9841, y = 0.1721. Orientation: theta = 0.0041 rad
# Control Node Position: x = 0.9842, y = 0.1721. Orientation: theta = 0.0041 rad
# Control Node Position: x = 0.9841, y = 0.1722. Orientation: theta = 0.0041 rad
# Control Node Position: x = 0.9841, y = 0.1721. Orientation: theta = 0.0042 rad
# t=0.0500, Error=1.758e-04, iters=35 du: [ 4.00000000e-03 -1.80507851e-05 -4.86913742e-04]
# Control Node Position: x = 0.9881, y = 0.1721. Orientation: theta = 0.0036 rad
# Control Node Position: x = 0.9882, y = 0.1721. Orientation: theta = 0.0036 rad
# Control Node Position: x = 0.9881, y = 0.1722. Orientation: theta = 0.0036 rad
# Control Node Position: x = 0.9881, y = 0.1721. Orientation: theta = 0.0037 rad
# t=0.0500, Error=1.708e-04, iters=36 du: [ 4.00000000e-03 -1.75217046e-05 -4.77417560e-04]
# Control Node Position: x = 0.9921, y = 0.1721. Orientation: theta = 0.0031 rad
# Control Node Position: x = 0.9922, y = 0.1721. Orientation: theta = 0.0031 rad
# Control Node Position: x = 0.9921, y = 0.1722. Orientation: theta = 0.0031 rad
# Control Node Position: x = 0.9921, y = 0.1721. Orientation: theta = 0.0032 rad
# t=0.0500, Error=1.657e-04, iters=37 du: [ 4.00000000e-03 -1.71580682e-05 -4.66297298e-04]
# Control Node Position: x = 0.9961, y = 0.1721. Orientation: theta = 0.0027 rad
# Control Node Position: x = 0.9962, y = 0.1721. Orientation: theta = 0.0027 rad
# Control Node Position: x = 0.9961, y = 0.1722. Orientation: theta = 0.0027 rad
# Control Node Position: x = 0.9961, y = 0.1721. Orientation: theta = 0.0028 rad
# t=0.0500, Error=1.608e-04, iters=38 du: [ 4.00000000e-03 -1.67218791e-05 -4.55071381e-04]
# Control Node Position: x = 1.0001, y = 0.1721. Orientation: theta = 0.0022 rad
# Control Node Position: x = 1.0002, y = 0.1721. Orientation: theta = 0.0022 rad
# Control Node Position: x = 1.0001, y = 0.1722. Orientation: theta = 0.0022 rad
# Control Node Position: x = 1.0001, y = 0.1721. Orientation: theta = 0.0023 rad
# t=0.0500, Error=1.558e-04, iters=39 du: [ 4.00000000e-03 -1.62810394e-05 -4.43743120e-04]
# current time: 0.1
# Control Node Position: x = 1.0041, y = 0.1720. Orientation: theta = 0.0018 rad
# Control Node Position: x = 1.0042, y = 0.1720. Orientation: theta = 0.0018 rad
# Control Node Position: x = 1.0041, y = 0.1721. Orientation: theta = 0.0018 rad
# Control Node Position: x = 1.0041, y = 0.1720. Orientation: theta = 0.0019 rad
# t=0.1000, Error=9.386e-03, iters=0 du: [-0.004 -0.004  0.004]
# Control Node Position: x = 1.0001, y = 0.1680. Orientation: theta = 0.0058 rad
# Control Node Position: x = 1.0002, y = 0.1680. Orientation: theta = 0.0058 rad
# Control Node Position: x = 1.0001, y = 0.1681. Orientation: theta = 0.0058 rad
# Control Node Position: x = 1.0001, y = 0.1680. Orientation: theta = 0.0059 rad
# t=0.1000, Error=8.842e-03, iters=1 du: [-0.004 -0.004  0.004]
# Control Node Position: x = 0.9961, y = 0.1640. Orientation: theta = 0.0098 rad
# Control Node Position: x = 0.9962, y = 0.1640. Orientation: theta = 0.0098 rad
# Control Node Position: x = 0.9961, y = 0.1641. Orientation: theta = 0.0098 rad
# Control Node Position: x = 0.9961, y = 0.1640. Orientation: theta = 0.0099 rad
# t=0.1000, Error=8.298e-03, iters=2 du: [-0.004 -0.004  0.004]
# Control Node Position: x = 0.9921, y = 0.1600. Orientation: theta = 0.0138 rad
# Control Node Position: x = 0.9922, y = 0.1600. Orientation: theta = 0.0138 rad
# Control Node Position: x = 0.9921, y = 0.1601. Orientation: theta = 0.0138 rad
# Control Node Position: x = 0.9921, y = 0.1600. Orientation: theta = 0.0139 rad
# t=0.1000, Error=7.752e-03, iters=3 du: [-0.004 -0.004  0.004]
# Control Node Position: x = 0.9881, y = 0.1560. Orientation: theta = 0.0178 rad
# Control Node Position: x = 0.9882, y = 0.1560. Orientation: theta = 0.0178 rad
# Control Node Position: x = 0.9881, y = 0.1561. Orientation: theta = 0.0178 rad
# Control Node Position: x = 0.9881, y = 0.1560. Orientation: theta = 0.0179 rad
# t=0.1000, Error=7.205e-03, iters=4 du: [-0.004      -0.004       0.00375628]
# Control Node Position: x = 0.9841, y = 0.1520. Orientation: theta = 0.0215 rad
# Control Node Position: x = 0.9842, y = 0.1520. Orientation: theta = 0.0215 rad
# Control Node Position: x = 0.9841, y = 0.1521. Orientation: theta = 0.0215 rad
# Control Node Position: x = 0.9841, y = 0.1520. Orientation: theta = 0.0216 rad
# t=0.1000, Error=6.657e-03, iters=5 du: [-0.004      -0.004       0.00315652]
# Control Node Position: x = 0.9801, y = 0.1480. Orientation: theta = 0.0247 rad
# Control Node Position: x = 0.9802, y = 0.1480. Orientation: theta = 0.0247 rad
# Control Node Position: x = 0.9801, y = 0.1481. Orientation: theta = 0.0247 rad
# Control Node Position: x = 0.9801, y = 0.1480. Orientation: theta = 0.0248 rad
# t=0.1000, Error=6.110e-03, iters=6 du: [-0.004      -0.004       0.00263291]
# Control Node Position: x = 0.9761, y = 0.1440. Orientation: theta = 0.0273 rad
# Control Node Position: x = 0.9762, y = 0.1440. Orientation: theta = 0.0273 rad
# Control Node Position: x = 0.9761, y = 0.1441. Orientation: theta = 0.0273 rad
# Control Node Position: x = 0.9761, y = 0.1440. Orientation: theta = 0.0274 rad
# t=0.1000, Error=5.564e-03, iters=7 du: [-0.004      -0.004       0.00217443]
# Control Node Position: x = 0.9721, y = 0.1400. Orientation: theta = 0.0295 rad
# Control Node Position: x = 0.9722, y = 0.1400. Orientation: theta = 0.0295 rad
# Control Node Position: x = 0.9721, y = 0.1401. Orientation: theta = 0.0295 rad
# Control Node Position: x = 0.9721, y = 0.1400. Orientation: theta = 0.0296 rad
# t=0.1000, Error=5.018e-03, iters=8 du: [-0.004     -0.004      0.0017657]
# Control Node Position: x = 0.9681, y = 0.1360. Orientation: theta = 0.0312 rad
# Control Node Position: x = 0.9682, y = 0.1360. Orientation: theta = 0.0312 rad
# Control Node Position: x = 0.9681, y = 0.1361. Orientation: theta = 0.0312 rad
# Control Node Position: x = 0.9681, y = 0.1360. Orientation: theta = 0.0313 rad
# t=0.1000, Error=4.472e-03, iters=9 du: [-0.004      -0.004       0.00141708]
# Control Node Position: x = 0.9641, y = 0.1320. Orientation: theta = 0.0327 rad
# Control Node Position: x = 0.9642, y = 0.1320. Orientation: theta = 0.0327 rad
# Control Node Position: x = 0.9641, y = 0.1321. Orientation: theta = 0.0327 rad
# Control Node Position: x = 0.9641, y = 0.1320. Orientation: theta = 0.0328 rad
# t=0.1000, Error=3.926e-03, iters=10 du: [-0.004      -0.004       0.00110666]
# Control Node Position: x = 0.9601, y = 0.1280. Orientation: theta = 0.0338 rad
# Control Node Position: x = 0.9602, y = 0.1280. Orientation: theta = 0.0338 rad
# Control Node Position: x = 0.9601, y = 0.1281. Orientation: theta = 0.0338 rad
# Control Node Position: x = 0.9601, y = 0.1280. Orientation: theta = 0.0339 rad
# t=0.1000, Error=3.380e-03, iters=11 du: [-0.004      -0.004       0.00083275]
# Control Node Position: x = 0.9561, y = 0.1240. Orientation: theta = 0.0346 rad
# Control Node Position: x = 0.9562, y = 0.1240. Orientation: theta = 0.0346 rad
# Control Node Position: x = 0.9561, y = 0.1241. Orientation: theta = 0.0346 rad
# Control Node Position: x = 0.9561, y = 0.1240. Orientation: theta = 0.0347 rad
# t=0.1000, Error=2.834e-03, iters=12 du: [-0.004      -0.004       0.00059166]
# Control Node Position: x = 0.9521, y = 0.1200. Orientation: theta = 0.0352 rad
# Control Node Position: x = 0.9522, y = 0.1200. Orientation: theta = 0.0352 rad
# Control Node Position: x = 0.9521, y = 0.1201. Orientation: theta = 0.0352 rad
# Control Node Position: x = 0.9521, y = 0.1200. Orientation: theta = 0.0353 rad
# t=0.1000, Error=2.287e-03, iters=13 du: [ 0.004      -0.004       0.00037986]
# Control Node Position: x = 0.9561, y = 0.1160. Orientation: theta = 0.0356 rad
# Control Node Position: x = 0.9562, y = 0.1160. Orientation: theta = 0.0356 rad
# Control Node Position: x = 0.9561, y = 0.1161. Orientation: theta = 0.0356 rad
# Control Node Position: x = 0.9561, y = 0.1160. Orientation: theta = 0.0357 rad
# t=0.1000, Error=1.729e-03, iters=14 du: [ 0.004      -0.004       0.00020876]
# Control Node Position: x = 0.9601, y = 0.1120. Orientation: theta = 0.0358 rad
# Control Node Position: x = 0.9602, y = 0.1120. Orientation: theta = 0.0358 rad
# Control Node Position: x = 0.9601, y = 0.1121. Orientation: theta = 0.0358 rad
# Control Node Position: x = 0.9601, y = 0.1120. Orientation: theta = 0.0359 rad
# t=0.1000, Error=1.174e-03, iters=15 du: [ 4.00000000e-03 -4.00000000e-03  6.19124386e-05]
# Control Node Position: x = 0.9641, y = 0.1080. Orientation: theta = 0.0358 rad
# Control Node Position: x = 0.9642, y = 0.1080. Orientation: theta = 0.0358 rad
# Control Node Position: x = 0.9641, y = 0.1081. Orientation: theta = 0.0358 rad
# Control Node Position: x = 0.9641, y = 0.1080. Orientation: theta = 0.0359 rad
# t=0.1000, Error=6.208e-04, iters=16 du: [ 4.00000000e-03 -3.85784608e-03 -6.20347800e-05]
# Control Node Position: x = 0.9681, y = 0.1042. Orientation: theta = 0.0358 rad
# current time: 0.15000000000000002
# Control Node Position: x = 0.9681, y = 0.1042. Orientation: theta = 0.0358 rad
# Control Node Position: x = 0.9682, y = 0.1042. Orientation: theta = 0.0358 rad
# Control Node Position: x = 0.9681, y = 0.1043. Orientation: theta = 0.0358 rad
# Control Node Position: x = 0.9681, y = 0.1042. Orientation: theta = 0.0359 rad
# t=0.1500, Error=6.306e-03, iters=0 du: [-0.004       0.004      -0.00059949]
# Control Node Position: x = 0.9641, y = 0.1082. Orientation: theta = 0.0352 rad
# Control Node Position: x = 0.9642, y = 0.1082. Orientation: theta = 0.0352 rad
# Control Node Position: x = 0.9641, y = 0.1083. Orientation: theta = 0.0352 rad
# Control Node Position: x = 0.9641, y = 0.1082. Orientation: theta = 0.0353 rad
# t=0.1500, Error=5.759e-03, iters=1 du: [-0.004       0.004      -0.00060033]
# Control Node Position: x = 0.9601, y = 0.1122. Orientation: theta = 0.0346 rad
# Control Node Position: x = 0.9602, y = 0.1122. Orientation: theta = 0.0346 rad
# Control Node Position: x = 0.9601, y = 0.1123. Orientation: theta = 0.0346 rad
# Control Node Position: x = 0.9601, y = 0.1122. Orientation: theta = 0.0347 rad
# t=0.1500, Error=5.211e-03, iters=2 du: [-0.004       0.004      -0.00059708]
# Control Node Position: x = 0.9561, y = 0.1162. Orientation: theta = 0.0340 rad
# Control Node Position: x = 0.9562, y = 0.1162. Orientation: theta = 0.0340 rad
# Control Node Position: x = 0.9561, y = 0.1163. Orientation: theta = 0.0340 rad
# Control Node Position: x = 0.9561, y = 0.1162. Orientation: theta = 0.0341 rad
# t=0.1500, Error=4.662e-03, iters=3 du: [-0.004      0.004     -0.0006012]
# Control Node Position: x = 0.9521, y = 0.1202. Orientation: theta = 0.0334 rad
# Control Node Position: x = 0.9522, y = 0.1202. Orientation: theta = 0.0334 rad
# Control Node Position: x = 0.9521, y = 0.1203. Orientation: theta = 0.0334 rad
# Control Node Position: x = 0.9521, y = 0.1202. Orientation: theta = 0.0335 rad
# t=0.1500, Error=4.111e-03, iters=4 du: [-0.004       0.004      -0.00060594]
# Control Node Position: x = 0.9481, y = 0.1242. Orientation: theta = 0.0328 rad
# Control Node Position: x = 0.9482, y = 0.1242. Orientation: theta = 0.0328 rad
# Control Node Position: x = 0.9481, y = 0.1243. Orientation: theta = 0.0328 rad
# Control Node Position: x = 0.9481, y = 0.1242. Orientation: theta = 0.0329 rad
# t=0.1500, Error=3.559e-03, iters=5 du: [-0.004       0.004      -0.00060887]
# Control Node Position: x = 0.9441, y = 0.1282. Orientation: theta = 0.0322 rad
# Control Node Position: x = 0.9442, y = 0.1282. Orientation: theta = 0.0322 rad
# Control Node Position: x = 0.9441, y = 0.1283. Orientation: theta = 0.0322 rad
# Control Node Position: x = 0.9441, y = 0.1282. Orientation: theta = 0.0323 rad
# t=0.1500, Error=3.005e-03, iters=6 du: [ 0.004       0.004      -0.00060684]
# Control Node Position: x = 0.9481, y = 0.1322. Orientation: theta = 0.0316 rad
# Control Node Position: x = 0.9482, y = 0.1322. Orientation: theta = 0.0316 rad
# Control Node Position: x = 0.9481, y = 0.1323. Orientation: theta = 0.0316 rad
# Control Node Position: x = 0.9481, y = 0.1322. Orientation: theta = 0.0317 rad
# t=0.1500, Error=2.451e-03, iters=7 du: [ 0.004       0.004      -0.00058291]
# Control Node Position: x = 0.9521, y = 0.1362. Orientation: theta = 0.0310 rad
# Control Node Position: x = 0.9522, y = 0.1362. Orientation: theta = 0.0310 rad
# Control Node Position: x = 0.9521, y = 0.1363. Orientation: theta = 0.0310 rad
# Control Node Position: x = 0.9521, y = 0.1362. Orientation: theta = 0.0311 rad
# t=0.1500, Error=1.898e-03, iters=8 du: [ 0.004       0.004      -0.00054641]
# Control Node Position: x = 0.9561, y = 0.1402. Orientation: theta = 0.0304 rad
# Control Node Position: x = 0.9562, y = 0.1402. Orientation: theta = 0.0304 rad
# Control Node Position: x = 0.9561, y = 0.1403. Orientation: theta = 0.0304 rad
# Control Node Position: x = 0.9561, y = 0.1402. Orientation: theta = 0.0305 rad
# t=0.1500, Error=1.347e-03, iters=9 du: [ 0.004       0.004      -0.00049439]
# Control Node Position: x = 0.9601, y = 0.1442. Orientation: theta = 0.0299 rad
# Control Node Position: x = 0.9602, y = 0.1442. Orientation: theta = 0.0299 rad
# Control Node Position: x = 0.9601, y = 0.1443. Orientation: theta = 0.0299 rad
# Control Node Position: x = 0.9601, y = 0.1442. Orientation: theta = 0.0300 rad
# t=0.1500, Error=7.974e-04, iters=10 du: [ 0.004       0.004      -0.00042518]
# Control Node Position: x = 0.9641, y = 0.1482. Orientation: theta = 0.0295 rad
# Control Node Position: x = 0.9642, y = 0.1482. Orientation: theta = 0.0295 rad
# Control Node Position: x = 0.9641, y = 0.1483. Orientation: theta = 0.0295 rad
# Control Node Position: x = 0.9641, y = 0.1482. Orientation: theta = 0.0296 rad
# t=0.1500, Error=2.495e-04, iters=11 du: [ 0.004       0.00255127 -0.00033657]
# Control Node Position: x = 0.9681, y = 0.1507. Orientation: theta = 0.0292 rad
# current time: 0.2
# Control Node Position: x = 0.9681, y = 0.1507. Orientation: theta = 0.0292 rad
# Control Node Position: x = 0.9682, y = 0.1507. Orientation: theta = 0.0292 rad
# Control Node Position: x = 0.9681, y = 0.1508. Orientation: theta = 0.0292 rad
# Control Node Position: x = 0.9681, y = 0.1507. Orientation: theta = 0.0293 rad
# t=0.2000, Error=1.932e-03, iters=0 du: [ 0.004      -0.004       0.00022507]
# Control Node Position: x = 0.9721, y = 0.1467. Orientation: theta = 0.0294 rad
# Control Node Position: x = 0.9722, y = 0.1467. Orientation: theta = 0.0294 rad
# Control Node Position: x = 0.9721, y = 0.1468. Orientation: theta = 0.0294 rad
# Control Node Position: x = 0.9721, y = 0.1467. Orientation: theta = 0.0295 rad
# t=0.2000, Error=1.378e-03, iters=1 du: [ 4.00000000e-03 -4.00000000e-03  6.09560312e-05]
# Control Node Position: x = 0.9761, y = 0.1427. Orientation: theta = 0.0295 rad
# Control Node Position: x = 0.9762, y = 0.1427. Orientation: theta = 0.0295 rad
# Control Node Position: x = 0.9761, y = 0.1428. Orientation: theta = 0.0295 rad
# Control Node Position: x = 0.9761, y = 0.1427. Orientation: theta = 0.0296 rad
# t=0.2000, Error=8.257e-04, iters=2 du: [ 4.0000000e-03 -4.0000000e-03 -7.8955551e-05]
# Control Node Position: x = 0.9801, y = 0.1387. Orientation: theta = 0.0294 rad
# Control Node Position: x = 0.9802, y = 0.1387. Orientation: theta = 0.0294 rad
# Control Node Position: x = 0.9801, y = 0.1388. Orientation: theta = 0.0294 rad
# Control Node Position: x = 0.9801, y = 0.1387. Orientation: theta = 0.0295 rad
# t=0.2000, Error=2.756e-04, iters=3 du: [ 0.004      -0.0012805  -0.00019447]
# Control Node Position: x = 0.9841, y = 0.1375. Orientation: theta = 0.0292 rad
# current time: 0.25
# Control Node Position: x = 0.9841, y = 0.1375. Orientation: theta = 0.0292 rad
# Control Node Position: x = 0.9842, y = 0.1375. Orientation: theta = 0.0292 rad
# Control Node Position: x = 0.9841, y = 0.1376. Orientation: theta = 0.0292 rad
# Control Node Position: x = 0.9841, y = 0.1375. Orientation: theta = 0.0293 rad
# t=0.2500, Error=4.684e-04, iters=0 du: [ 0.004       0.00394701 -0.00032212]
# Control Node Position: x = 0.9881, y = 0.1414. Orientation: theta = 0.0289 rad
# current time: 0.3
# Control Node Position: x = 0.9881, y = 0.1414. Orientation: theta = 0.0289 rad
# Control Node Position: x = 0.9882, y = 0.1414. Orientation: theta = 0.0289 rad
# Control Node Position: x = 0.9881, y = 0.1415. Orientation: theta = 0.0289 rad
# Control Node Position: x = 0.9881, y = 0.1414. Orientation: theta = 0.0290 rad
# t=0.3000, Error=1.188e-04, iters=0 du: [ 0.004      -0.0002246  -0.00020792]
# Control Node Position: x = 0.9921, y = 0.1412. Orientation: theta = 0.0287 rad
# current time: 0.35
# Control Node Position: x = 0.9921, y = 0.1412. Orientation: theta = 0.0287 rad
# Control Node Position: x = 0.9922, y = 0.1412. Orientation: theta = 0.0287 rad
# Control Node Position: x = 0.9921, y = 0.1413. Orientation: theta = 0.0287 rad
# Control Node Position: x = 0.9921, y = 0.1412. Orientation: theta = 0.0288 rad
# t=0.3500, Error=1.470e-04, iters=0 du: [ 0.004      -0.0004735  -0.00018969]
# Control Node Position: x = 0.9961, y = 0.1407. Orientation: theta = 0.0285 rad
# current time: 0.39999999999999997
# Control Node Position: x = 0.9961, y = 0.1407. Orientation: theta = 0.0285 rad
# current time: 0.44999999999999996
# Control Node Position: x = 0.9961, y = 0.1407. Orientation: theta = 0.0285 rad
# current time: 0.49999999999999994
# Control Node Position: x = 0.9961, y = 0.1407. Orientation: theta = 0.0285 rad
# current time: 0.5499999999999999
# Control Node Position: x = 0.9961, y = 0.1407. Orientation: theta = 0.0285 rad
# current time: 0.6
# Control Node Position: x = 0.9961, y = 0.1407. Orientation: theta = 0.0285 rad
# Control Node Position: x = 0.9962, y = 0.1407. Orientation: theta = 0.0285 rad
# Control Node Position: x = 0.9961, y = 0.1408. Orientation: theta = 0.0285 rad
# Control Node Position: x = 0.9961, y = 0.1407. Orientation: theta = 0.0286 rad
# t=0.6000, Error=1.026e-04, iters=0 du: [ 0.004      -0.0002088  -0.00019547]
# Control Node Position: x = 1.0001, y = 0.1405. Orientation: theta = 0.0283 rad
# current time: 0.65
# Control Node Position: x = 1.0001, y = 0.1405. Orientation: theta = 0.0283 rad
# Control Node Position: x = 1.0002, y = 0.1405. Orientation: theta = 0.0283 rad
# Control Node Position: x = 1.0001, y = 0.1406. Orientation: theta = 0.0283 rad
# Control Node Position: x = 1.0001, y = 0.1405. Orientation: theta = 0.0284 rad
# t=0.6500, Error=1.092e-04, iters=0 du: [ 0.004      -0.00028942 -0.00018454]
# Control Node Position: x = 1.0041, y = 0.1402. Orientation: theta = 0.0281 rad
# current time: 0.7000000000000001
# Control Node Position: x = 1.0041, y = 0.1402. Orientation: theta = 0.0281 rad
# current time: 0.7500000000000001
# Control Node Position: x = 1.0041, y = 0.1402. Orientation: theta = 0.0281 rad
# current time: 0.8000000000000002
# Control Node Position: x = 1.0041, y = 0.1402. Orientation: theta = 0.0281 rad
# current time: 0.8500000000000002
# Control Node Position: x = 1.0041, y = 0.1402. Orientation: theta = 0.0281 rad
# current time: 0.9000000000000002
# Control Node Position: x = 1.0041, y = 0.1402. Orientation: theta = 0.0281 rad
# current time: 0.9500000000000003

# %%
# Plot the middle node information as a function of time
t_arr = np.linspace(0, totalTime, Nsteps)

control_x = control_state[:, 0]
control_y = control_state[:, 1]
control_angle = control_state[:, 2] * 180 / np.pi # convert to degrees

plt.figure(2)
plt.plot(t_arr, control_x, 'ko-')
plt.xlabel('Time (s)')
plt.ylabel('Control Node Position (m)')
plt.title('Control Node X Position vs. Time')
plt.show()
if saveImage:
  plt.savefig('control_Xnode_position.png')

plt.figure(3)
plt.plot(t_arr, control_y, 'ko-')
plt.xlabel('Time (s)')
plt.ylabel('Control Node Position (m)')
plt.title('Control Node  Y Position vs. Time')
plt.show()
if saveImage:
  plt.savefig('control_Ynode_position.png')

plt.figure(4)
plt.plot(t_arr, control_angle, 'ko-')
plt.xlabel('Time (s)')
plt.ylabel('Turning angle (degrees)')
plt.title('Turning angle vs. Time')
plt.show()
if saveImage:
  plt.savefig('turning_angle.png')
